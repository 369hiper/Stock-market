# %%
# %pip install numpy

# %pip install matplotlib
# %pip install pandas
# %pip install seaborn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: numpy in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (2.2.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: matplotlib in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (3.10.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pandas in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from pandas) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\onedrive - msft\documents\01_stock_project\01eur-usd\stock-market-prediction-main\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load and Check Data

# %%
bitcoin_data = pd.read_csv("Bitcoin.csv")

# %%
bitcoin_data.columns
# Out:
# Index(['SNo', 'Name', 'Symbol', 'Date', 'High', 'Low', 'Open', 'Close',
#        'Volume', 'Marketcap'],
#       dtype='object')

# %%
bitcoin_data.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
bitcoin_data.describe()
# Out:
#                SNo          High           Low          Open         Close  \
# count  2991.000000   2991.000000   2991.000000   2991.000000   2991.000000
# mean   1496.000000   6893.326038   6486.009539   6700.146240   6711.290443
# std     863.571653  11642.832456  10869.032130  11288.043736  11298.141921
# min       1.000000     74.561096     65.526001     68.504997     68.431000
# 25%     748.500000    436.179001    422.879486    430.445496    430.569489
# 50%    1496.000000   2387.610107   2178.500000   2269.889893   2286.409912
# 75%    2243.500000   8733.926948   8289.800459   8569.656494   8576.238715
# max    2991.000000  64863.098908  62208.964366  63523.754869  63503.457930
#
#              Volume     Marketcap
# count  2.991000e+03  2.991000e+03
# mean   1.090633e+10  1.208761e+11
# std    1.888895e+10  2.109438e+11
# min    0.000000e+00  7.784112e+08
# 25%    3.036725e+07  6.305579e+09
# 50%    9.460360e+08  3.741503e+10
# 75%    1.592015e+10  1.499957e+11
# max    3.509679e+11  1.186364e+12

# %%
bitcoin_data.tail()
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 2986  33549.600177  33897.048590  3.872897e+10  6.354508e+11
# 2987  33854.421362  34668.548402  2.438396e+10  6.499397e+11
# 2988  34665.564866  35287.779766  2.492431e+10  6.615748e+11
# 2989  35284.344430  33746.002456  2.672155e+10  6.326962e+11
# 2990  33723.509655  34235.193451  2.650126e+10  6.418992e+11

# %%
print(bitcoin_data.dtypes)
# Out:
# SNo            int64
# Name          object
# Symbol        object
# Date          object
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Marketcap    float64
# dtype: object

# %% [markdown]
# ## Convert the 'Date' column to datetime format and sort the dataset by date.

# %%
bitcoin_data['Date'] = pd.to_datetime(bitcoin_data['Date'])
bitcoin_data.sort_values(by='Date', inplace=True)

# %%
# Time Series Trend
plt.figure(figsize=(14, 7))
# Opening Price Chart
