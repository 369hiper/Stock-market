# %%
import requests

# %%
URL = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MSFT&outputsize=full&apikey=demo"

# %%
r = requests.get(URL)

# %%
print(r.content)
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Daily Prices (open, high, low, close) and Volumes",
#         "2. Symbol": "MSFT",
#         "3. Last Refreshed": "2019-11-25",
#         "4. Output Size": "Full size",
#         "5. Time Zone": "US/Eastern"
#     },
#     "Time Series (Daily)": {
#         "2019-11-25": {
#             "1. open": "150.0000",
#             "2. high": "151.3500",
#             "3. low": "149.9200",
#             "4. close": "151.2300",
#             "5. volume": "22153493"
#         },
#         "2019-11-22": {
#             "1. open": "150.0700",
#             "2. high": "150.3000",
#             "3. low": "148.8200",
#             "4. close": "149.5900",
#             "5. volume": "15841680"
#         },
#         "2019-11-21": {
#             "1. open": "149.4000",
#             "2. high": "149.8000",
#             "3. low": "148.5010",
#             "4. close": "149.4800",
#             "5. volume": "18576083"
#         },
# ...

# %%
# Find the date 
# Get the Columns
# Create an excel file

# %% [markdown]
# # Steps to Implement the Image Processing Models to Implement and Interpret Trade Signals
# 1. Extract Images in real time
# ![image.png](attachment:image.png)
# 2. # Check for the calls
# ![image.png](attachment:image.png)
# 3. # If it's a call fill in the particulars in the text message and Send it on Telegram
